# %%
from io import StringIO

import matplotlib
from matplotlib import pyplot as plt
from matplotlib.colors import LinearSegmentedColormap as mpl_LinearSegmentedColormap
import numpy as np
import pandas as pd
import seaborn as sns
from teeplot import teeplot as tp

# %%
from dishpylib.pyhelpers import get_env_context
from dishpylib.pyhelpers import get_git_revision_hash
from dishpylib.pyhelpers import make_timestamp
from dishpylib.pyhelpers import print_runtime

# %%
print_runtime()
# Out:
# context: ci
# hostname: 93e075c25471
# interpreter: 3.8.15 (default, Oct 12 2022, 19:14:39)  [GCC 7.5.0]
# revision: 370c9ae9b
# timestamp: 2022-11-08T05:07:23Z00:00
#
# IPython==7.16.1
# matplotlib==3.5.2
# matplotlib==3.5.2
# numpy==1.19.5
# pandas==1.1.2
# seaborn==0.11.2
# teeplot==0.1.1

# %%
morph_csv = StringIO('''Stint,Morph,Series
0,a,16005
1,b,16005
2,c,16005
3,b,16005
4,b,16005
5,b,16005
6,b,16005
7,b,16005
8,b,16005
9,b,16005
10,b,16005
11,b,16005
12,b,16005
13,b,16005
14,d,16005
15,e,16005
16,e,16005
17,e,16005
18,e,16005
19,e,16005
20,e,16005
21,e,16005
22,e,16005
23,e,16005
24,e,16005
25,e,16005
26,b,16005
27,e,16005
28,b,16005
29,e,16005
30,e,16005
31,e,16005
32,e,16005
33,e,16005
34,e,16005
35,e,16005
36,e,16005
37,e,16005
38,e,16005
39,f,16005
40,e,16005
41,e,16005
42,e,16005
43,e,16005
44,e,16005
45,g,16005
46,g,16005
47,g,16005
48,g,16005
49,g,16005
50,g,16005
51,g,16005
52,g,16005
53,e,16005
54,g,16005
55,g,16005
56,g,16005
57,g,16005
58,g,16005
59,h,16005
60,g,16005
61,e,16005
62,g,16005
63,g,16005
64,e,16005
65,e,16005
66,g,16005
67,g,16005
68,e,16005
69,g,16005
70,e,16005
71,e,16005
72,e,16005
73,g,16005
74,i,16005
75,i,16005
76,g,16005
77,i,16005
78,e,16005
79,g,16005
80,e,16005
81,e,16005
82,e,16005
83,e,16005
84,e,16005
85,e,16005
86,e,16005
87,e,16005
88,e,16005
89,g,16005
90,g,16005
91,e,16005
92,i,16005
93,e,16005
94,e,16005
95,b,16005
96,b,16005
97,h,16005
98,e,16005
99,e,16005
100,j,16005
''')

df_morph = pd.read_csv(morph_csv)

# %%
color_key = {
    'a' : 'tab:blue',
    'b' : 'tab:orange',
    'c' : 'tab:green',
    'd' : 'tab:red',
    'e' : 'tab:purple',
    'f' : 'tab:brown',
    'g' : 'tab:pink',
    'h' : 'tab:gray',
    'i' : 'tab:olive',
    'j' : 'tab:cyan',
}

# %%
morph_key = {
    row['Stint'] : row['Morph']
    for idx, row in df_morph.iterrows()
}

# %%
background_key = {
    "lowestroot-immediatepredecessor-battles"
        : "Without",
    "control-immediatepredecessor-battles-dosecorrected-withfocalstrainbaselinebioticbackground-withmut"
        : "Prefatory Focal Strain",
    "immediatepredecessor-simuls-nobioticbackground-withmut"
        : "Without",
    "control-immediatepredecessor-simuls-dosecorrected-nodiversitymaintenance-withfocalstrainbaselinebioticbackground-withmut"
        : "Prefatory Focal Strain\n(no diversity maint.)",
    "control-immediatepredecessor-simuls-dosecorrected-withfocalstrainbaselinebioticbackground-withmut"
        : "Prefatory Focal Strain",
}

# %%
def subject_key(setup: str) -> str:
    if 'simul' in setup or 'competition' in setup:
        return 'Specimen'
    elif 'battle' in setup:
        return 'Population'
    else:
        assert False

# %%
dfs = []
for setup in (
    "lowestroot-immediatepredecessor-battles",
    "control-immediatepredecessor-battles-dosecorrected-withfocalstrainbaselinebioticbackground-withmut",
    "immediatepredecessor-simuls-nobioticbackground-withmut",
    "control-immediatepredecessor-simuls-dosecorrected-nodiversitymaintenance-withfocalstrainbaselinebioticbackground-withmut",
    "control-immediatepredecessor-simuls-dosecorrected-withfocalstrainbaselinebioticbackground-withmut",
):    
    print(setup)
    df = pd.read_csv(
        f"https://prq49.s3.us-east-2.amazonaws.com/endeavor%3D16/{setup}/stage%3D2%2Bwhat%3Dcollated/a%3Dconcat%2Bhow%3Dmanual%2Bext%3D.csv"    
    )
    df["setup"] = setup
    if "Fitness Differential Focal" not in df:
        df["Fitness Differential Focal"] = df["Fitness Differential"]
    if "Focal Prevalence" not in df:
        df["Focal Prevalence"] = df["Prevalence"]
    if "Focal Abundance" not in df:
        df["Focal Abundance"] = df["Abundance"]

    df['Positive Fitness Differential Focal'] = df['Focal Prevalence'] > 0.5

    dfs.append(df)
    
df = pd.concat(dfs, ignore_index=True)
df['Biotic Background'] = df['setup'].apply(lambda setup: background_key[setup])
df['Assay Subject'] = df['setup'].apply(lambda setup: subject_key(setup))
df['Assay Subject'] = df['setup'].apply(lambda setup: subject_key(setup))

df['Competition Stint Num Setups'] = df.groupby(
    "Competition Stint"
)["setup"].transform('nunique')
# Out:
# lowestroot-immediatepredecessor-battles
# control-immediatepredecessor-battles-dosecorrected-withfocalstrainbaselinebioticbackground-withmut
# immediatepredecessor-simuls-nobioticbackground-withmut
# control-immediatepredecessor-simuls-dosecorrected-nodiversitymaintenance-withfocalstrainbaselinebioticbackground-withmut
# control-immediatepredecessor-simuls-dosecorrected-withfocalstrainbaselinebioticbackground-withmut

# %%
print(len(df))
print(len(df[df['Root ID'] == 1]))
digest = '{:x}'.format(pd.util.hash_pandas_object( df ).sum())
digest
# Out:
# 15780
# 6600
# '58e3798ca2e07a48'

# %%
def barplot(*args, **kwargs):
    ax = sns.barplot(
        *args,
        **kwargs,
    )
    sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

    plt.axhline(0.5)
    plt.gcf().set_size_inches(20, 5)

    data = kwargs["data"]
    x = kwargs["x"]
    xticks = sorted(data[x].unique())
    ax.set_xticklabels(f"{i:{'-'}{'<'}{3}}({morph_key[i]})██" for i in xticks)
    ax.tick_params(axis='x', labelrotation=270)
    ax.grid(axis='y')
    ax.set_axisbelow(True)
    
    for idx, tick in zip(xticks, ax.get_xticklabels()):
        tick.set_color(color_key[morph_key[idx]])
        tick.set_fontfamily("monospace")
        tick.set_fontname("Fira Mono")

def facet_barplot(data, **kwargs):
    g = sns.FacetGrid(
        data,
        sharey=False, 
        row="Assay Subject",
        row_order=["Specimen", "Population"],
        margin_titles=True,
    )
    fig = g.map_dataframe(
        barplot,
        **kwargs,
    )
    plt.gcf().set_size_inches(20, 10)
    plt.gcf().tight_layout()
    g.add_legend()

tp.tee(
    facet_barplot,
    data=df[
        (df['Root ID'] == 1) 
        & (df['Competition Stint Num Setups'] > 2)
    ],
    x='Competition Stint',
    y='Focal Prevalence',
    hue='Biotic Background',
    ci=95,
    hue_order=sorted(df["Biotic Background"].unique()),
    palette=sns.color_palette("tab10"),
    teeplot_outattrs={
        "a": "baselinecontrol",
    },
)
# Out:
# findfont: Font family ['Fira Mono'] not found. Falling back to DejaVu Sans.
# teeplots/a=baselinecontrol+hue=biotic-background+viz=facet-barplot+x=competition-stint+y=focal-prevalence+ext=.pdf
# teeplots/a=baselinecontrol+hue=biotic-background+viz=facet-barplot+x=competition-stint+y=focal-prevalence+ext=.png

# %%
def boxplot(*args, **kwargs):
    ax = sns.boxplot(
        *args,
        **kwargs,
    )
    sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

    plt.axhline(0.5)
    plt.gcf().set_size_inches(20, 5)

    data = kwargs["data"]
    x = kwargs["x"]
    xticks = sorted(data[x].unique())
    ax.set_xticklabels(f"{i:{'-'}{'<'}{3}}({morph_key[i]})██" for i in xticks)
    ax.tick_params(axis='x', labelrotation=270)
    ax.grid(axis='y')
    ax.set_axisbelow(True)
    
    for idx, tick in zip(xticks, ax.get_xticklabels()):
        tick.set_color(color_key[morph_key[idx]])
        tick.set_fontfamily("monospace")
        tick.set_fontname("Fira Mono")

def facet_boxplot(data, **kwargs):
    g = sns.FacetGrid(
        data,
        sharey=False, 
        row="Assay Subject",
        row_order=["Specimen", "Population"],
        margin_titles=True,
    )
    fig = g.map_dataframe(
        boxplot,
        **kwargs,
    )
    plt.gcf().set_size_inches(20, 10)
    plt.gcf().tight_layout()
    g.add_legend()

tp.tee(
    facet_boxplot,
    data=df[
        (df['Root ID'] == 1) 
        & (df['Competition Stint Num Setups'] > 2)
    ],
    x='Competition Stint',
    y='Focal Prevalence',
    hue='Biotic Background',
    hue_order=sorted(df["Biotic Background"].unique()),
    palette=sns.color_palette("tab10"),
    teeplot_outattrs={
        "a": "baselinecontrol",
    },
)
# Out:
# teeplots/a=baselinecontrol+hue=biotic-background+viz=facet-boxplot+x=competition-stint+y=focal-prevalence+ext=.pdf
# teeplots/a=baselinecontrol+hue=biotic-background+viz=facet-boxplot+x=competition-stint+y=focal-prevalence+ext=.png

# %%
def countplot(*args, **kwargs):
    ax = sns.countplot(
        *args,
        **kwargs,
    )

    plt.axhline(2.5)
    plt.axhline(17.5)
    plt.gcf().set_size_inches(20, 5)
    ax.set_ylim(0,20)

    for item in ax.containers:
        ax.bar_label(item)

    data = kwargs["data"]
    x = kwargs["x"]
    xticks = sorted(data[x].unique())
    ax.set_xticklabels(f"{i:{'-'}{'<'}{3}}({morph_key[i]})██" for i in xticks)
    ax.tick_params(axis='x', labelrotation=270)
    ax.grid(axis='y')
    ax.set_axisbelow(True)
    
    for idx, tick in zip(xticks, ax.get_xticklabels()):
        tick.set_color(color_key[morph_key[idx]])
        tick.set_fontfamily("monospace")
        tick.set_fontname("Fira Mono")

def facet_countplot(data, **kwargs):
    g = sns.FacetGrid(
        data,
        sharey=False, 
        row="Assay Subject",
        row_order=["Specimen", "Population"],
        margin_titles=True,
    )
    fig = g.map_dataframe(
        countplot,
        **kwargs,
    )
    plt.gcf().set_size_inches(20, 10)
    plt.gcf().tight_layout()
    g.add_legend()
                
tp.tee(
    facet_countplot,
    data=df[
        (df['Root ID'] == 1)
        & (df['Competition Stint Num Setups'] > 2)
        & df['Positive Fitness Differential Focal']
    ],
    x="Competition Stint",
    hue='Biotic Background',
    hue_order=sorted(df["Biotic Background"].unique()),
    palette=sns.color_palette("tab10"),
    teeplot_outattrs={
        "a": "baselinecontrol",
    },
)
# Out:
# teeplots/a=baselinecontrol+hue=biotic-background+viz=facet-countplot+x=competition-stint+ext=.pdf
# teeplots/a=baselinecontrol+hue=biotic-background+viz=facet-countplot+x=competition-stint+ext=.png

# %%
def boxplot(*args, **kwargs):
    ax = sns.boxplot(
        *args,
        **kwargs,
    )

    plt.axhline(0.5)
    plt.gcf().set_size_inches(20, 5)

    data = kwargs["data"]
    x = kwargs["x"]
    xticks = sorted(data[x].unique())
    ax.set_xticklabels(f"{i:{'-'}{'<'}{3}}({morph_key[i]})██" for i in xticks)
    ax.tick_params(axis='x', labelrotation=270)
    ax.grid(axis='y')
    ax.set_axisbelow(True)
    
    for idx, tick in zip(xticks, ax.get_xticklabels()):
        tick.set_color(color_key[morph_key[idx]])
        tick.set_fontfamily("monospace")
        tick.set_fontname("Fira Mono")
    
def facet_boxplot(data, **kwargs):
    g = sns.FacetGrid(
        data,
        sharey=False, 
        row="Assay Subject",
        row_order=["Specimen", "Population"],
        margin_titles=True,
    )
    fig = g.map_dataframe(
        boxplot,
        **kwargs,
    )
    plt.gcf().set_size_inches(20, 10)
    plt.gcf().tight_layout()
    g.add_legend()
    
tp.tee(
    facet_boxplot,
    data=df[
        (df['Root ID'] == 1) 
        & (df['Competition Stint Num Setups'] > 2)
    ],
    x='Competition Stint',
    y='Update',
    hue='Biotic Background',
    hue_order=sorted(df["Biotic Background"].unique()),
    palette=sns.color_palette("tab10"),
    teeplot_outattrs={
        "a": "baselinecontrol",
    },
)
# Out:
# teeplots/a=baselinecontrol+hue=biotic-background+viz=facet-boxplot+x=competition-stint+y=update+ext=.pdf
# teeplots/a=baselinecontrol+hue=biotic-background+viz=facet-boxplot+x=competition-stint+y=update+ext=.png

# %%
# adapted from https://stackoverflow.com/a/38887138
colors = ('red', 'yellow', 'green')
cmap = mpl_LinearSegmentedColormap.from_list('Custom', colors, len(colors))

def plot_heatmap(data, **kwargs):
    win_df = data[
        (df['Root ID'] == 1) 
        & (df['Competition Stint Num Setups'] > 2)
        & (data["Competition Stint"] > 0)
    ].groupby(
        ["Biotic Background", "Competition Stint"]
    )['Positive Fitness Differential Focal'].agg([len, sum]).reset_index()

    win_df["Outcome"] = win_df.apply(
        lambda row: -1 if row["sum"] < 3 else 1 if row["sum"] > 17 else 0,
        axis=1,
    ) 
    assert set(win_df["len"]) == {20}
    
    pivot_df = win_df.pivot("Biotic Background", "Competition Stint", "Outcome")
    
    ax = sns.heatmap(pivot_df, cmap=cmap, cbar_kws={"location": "top", "aspect": 100, "shrink": 1.0}, linewidth=1)
    colorbar = ax.collections[0].colorbar
    colorbar.set_ticks([-0.667, 0, 0.667])
    colorbar.set_ticklabels(['Significant Fitness Loss $(p < 0.005)$', 'Neutral', 'Significant Fitness Gain $(p < 0.005)$'])
    if {*data["Assay Subject"].unique()} == {"Population"}:
        colorbar.remove()
    
    stints = sorted(win_df["Competition Stint"].unique())
    ax.set_xticks(np.array(range(len(stints))) + 0.5)
    ax.set_xticklabels(f"{i:{'-'}{'<'}{3}}({morph_key[i]})██" for i in stints)
    ax.tick_params(axis='y', labelrotation=0)
    ax.tick_params(axis='x', labelrotation=270)
    
    for idx, tick in enumerate(ax.get_xticklabels()):
        tick.set_color(color_key[morph_key[idx+1]])
        tick.set_fontfamily("monospace")
        tick.set_fontname("Fira Mono")

def facet_heatmap(data, x, y, hue):
    g = sns.FacetGrid(
        data, 
        sharey=False, 
        row="Assay Subject",
        row_order=["Specimen", "Population"],
        margin_titles=True,
    )
    fig = g.map_dataframe(plot_heatmap)

    plt.gcf().set_size_inches(30, 10)
    plt.gcf().tight_layout()

tp.tee(
    facet_heatmap,
    data=df[
        (df['Root ID'] == 1) 
        & (df['Competition Stint Num Setups'] > 2)
    ],
    x="Biotic Background",
    y="Competition Stint",
    hue="Fitness Gain or Loss",
    teeplot_outattrs={
        "a": "baselinecontrol",
    },
)
# Out:
# <ipython-input-15-1741bab7efa0>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   win_df = data[
# <ipython-input-15-1741bab7efa0>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   win_df = data[
# teeplots/a=baselinecontrol+hue=fitness-gain-or-loss+viz=facet-heatmap+x=biotic-background+y=competition-stint+ext=.pdf
# teeplots/a=baselinecontrol+hue=fitness-gain-or-loss+viz=facet-heatmap+x=biotic-background+y=competition-stint+ext=.png
