# %%
import boto3
import botocore
import pandas as pd
from pandas.util import hash_pandas_object

# %% [markdown]
# # get data

# %%
s3_handle = boto3.resource(
    's3',
    region_name="us-east-2",
    config=botocore.config.Config(
        signature_version=botocore.UNSIGNED,
    ),
)
bucket_handle = s3_handle.Bucket('prq49')

series_profiles, = bucket_handle.objects.filter(
    Prefix=f'endeavor=16/stage=8+what=elaborated/',
)

# %%
df = pd.read_csv(
    f's3://prq49/{series_profiles.key}',
    compression='xz',
)
digest = '{:x}'.format(hash_pandas_object( df ).sum())
digest
# Out:
# '581a93929506b064'

# %%
for stint in df['Stint'].unique():
    exec(f'df{stint} = df[ df["Stint"] == {stint} ]')

# %% [markdown]
# # preview data

# %%
df
# Out:
#                 Repro  Endeavor  Slurm Job ID  N_THREADS  RUN  RUN_UPDATES  \
# 0    L0N1M89lkIFX22bs        16      20670384          4    1            0
# 1    cHIpq1wHlerAQ3Yk        16      20670385          4    1            0
# 2    jIPhliWgeZAmuqPo        16      20670386          4    1            0
# 3    uPoUAkwcIQ9o9Urz        16      20670387          4    1            0
# 4    xj0TrZcKZiMg9qCe        16      20670388          4    1            0
# ..                ...       ...           ...        ...  ...          ...
# 228  hC4bUunfl10ht5V0        16      21152208          4    1            0
# 229  oznhNVSyEtDF6Zpa        16      21150878          4    1            0
# 230  1LTngLjlXTWjSbIn        16      21150009          4    1            0
# 231  93xX7fLu5wdKmPEY        16      21150023          4    1            0
# 232  9LWM9tTsZvTJ4CIJ        16      21147967          4    1            0
#
#      RUN_SECONDS  MAIN_TIMEOUT_SECONDS  END_SNAPSHOT_TIMEOUT_SECONDS  \
# 0          10800                 13500                          1200
# 1          10800                 13500                          1200
# 2          10800                 13500                          1200
# 3          10800                 13500                          1200
# 4          10800                 13500                          1200
# ..           ...                   ...                           ...
# 228        10800                 13500                          1200
# 229        10800                 13500                          1200
# 230        10800                 13500                          1200
# 231        10800                 13500                          1200
# 232        10800                 13500                          1200
#
#      LOG_FREQ  ...  Phenotype Complexity Delta %  \
# 0          20  ...                      3.538462
# 1          20  ...                      6.521739
# 2          20  ...                     -0.555556
# 3          20  ...                      1.387755
# 4          20  ...                      2.875000
# ..        ...  ...                           ...
# 228        20  ...                           NaN
# 229        20  ...                           NaN
# 230        20  ...                           NaN
# 231        20  ...                           NaN
# 232        20  ...                           NaN
#
#      Phenotype Complexity Delta Sign  Predecessor Battle Outcome  \
# 0                               True               indeterminate
# 1                               True               indeterminate
# 2                              False   less fit than predecessor
# 3                               True               indeterminate
# 4                               True   less fit than predecessor
# ..                               ...                         ...
# 228                            False   more fit than predecessor
# 229                            False   more fit than predecessor
# 230                            False   more fit than predecessor
# 231                            False   more fit than predecessor
# 232                            False   more fit than predecessor
#
#      Neutral Phenotypic Variation Under Mutation  \
# 0                                          -0.15
# 1                                           0.80
# 2                                          -0.05
# 3                                           1.00
# 4                                          -0.25
# ..                                           ...
# 228                                         0.70
# 229                                         0.60
# 230                                         0.85
# 231                                         0.75
# 232                                         0.85
#
#     Fraction Phenotypic Variation That Is Neutral Under Mutation  \
# 0                                                 -inf
# 1                                                 0.80
# 2                                                 -inf
# 3                                                 1.00
# 4                                                 -inf
# ..                                                 ...
# 228                                               0.70
# 229                                               0.60
# 230                                               0.85
# 231                                               0.75
# 232                                               0.85
#
#      Num Less Fit Under State Exchanges  Num Less Fit Under State Rotates  \
# 0                                  18.0                               2.0
# 1                                   1.0                               1.0
# 2                                   1.0                               1.0
# 3                                   0.0                               0.0
# 4                                   3.0                               4.0
# ..                                  ...                               ...
# 228                                 3.0                               1.0
# 229                                 1.0                               2.0
# 230                                 2.0                               2.0
# 231                                 2.0                               2.0
# 232                                 1.0                               1.0
#
#      Num Less Fit Under State Perturbation  Cardinal Interface Complexity  \
# 0                                       18                           18.0
# 1                                        1                            2.0
# 2                                        1                            2.0
# 3                                        0                            0.0
# 4                                        5                            5.0
# ..                                     ...                            ...
# 228                                      3                            4.0
# 229                                      2                            6.0
# 230                                      3                            4.0
# 231                                      2                            4.0
# 232                                      1                            2.0
#
#      Cell Interface Complexity
# 0                         18.0
# 1                          2.0
# 2                          2.0
# 3                          0.0
# 4                          5.0
# ..                         ...
# 228                        4.0
# 229                        6.0
# 230                        4.0
# 231                        4.0
# 232                        2.0
#
# [233 rows x 630 columns]

# %% [markdown]
# # list columns

# %%
for col in df.columns:
    print(col)
# Out:
# Repro
# Endeavor
# Slurm Job ID
# N_THREADS
# RUN
# RUN_UPDATES
# RUN_SECONDS
# MAIN_TIMEOUT_SECONDS
# END_SNAPSHOT_TIMEOUT_SECONDS
# LOG_FREQ
# ASYNCHRONOUS
# SYNC_FREQ_MILLISECONDS
# RNG_PRESEED
# THROW_ON_EXTINCTION
# RUN_SLUG
# PHENOTYPIC_DIVERGENCE_N_UPDATES
# PHENOTYPIC_DIVERGENCE_N_CELLS
# STINT
# SERIES
# REPLICATE
# TREATMENT
# SEED_FILL_FRACTION
# GENESIS
# N_CELLS
# WEAK_SCALING
# N_DIMS
# GROUP_EXPIRATION_DURATIONS
# CELL_AGE_DURATION
# MIN_START_RESOURCE
# MAX_START_RESOURCE
# RESOURCE_DECAY
# APOP_RECOVERY_FRAC
# SPAWN_DEFENSE_COST
# BASE_HARVEST_RATE
# COLLECTIVE_HARVEST_RATE
# OPTIMAL_QUORUM_COUNT
# P_SET_QUORUM_BIT
# QUORUM_CAP
# P_QUORUM_CAP_KILL
# PROGRAM_START_SIZE
# PROGRAM_MAX_SIZE
# MUTATION_RATE
# POINT_MUTATION_RATE
# SEQUENCE_DEFECT_RATE
# MINOR_SEQUENCE_MUTATION_BOUND
# SEVERE_SEQUENCE_MUTATION_RATE
# HARDWARE_EXECUTION_ROUNDS
# HARDWARE_EXECUTION_CYCLES
# CONTROLLER_MAPPED_STATE_DEFECT_RATE
# APOPTOSIS_SERVICE_FREQUENCY
# BIRTH_SETUP_SERVICE_FREQUENCY
# CELL_AGE_SERVICE_FREQUENCY
# CONDUIT_FLUSH_SERVICE_FREQUENCY
# COLLECTIVE_HARVESTING_SERVICE_FREQUENCY
# CPU_EXECUTION_SERVICE_FREQUENCY
# GROUP_EXPIRATION_SERVICE_FREQUENCY
# RUNNING_LOG_PURGE_SERVICE_FREQUENCY
# DIVERSITY_MAINTENANCE_SERVICE_FREQUENCY
# DIVERSITY_MAINTENANCE_PREVALENCE
# STINT_DIVERSITY_MAINTENANCE_SERVICE_FREQUENCY
# STINT_DIVERSITY_MAINTENANCE_PREVALENCE
# DECAY_TO_BASELINE_SERVICE_FREQUENCY
# EPOCH_ADVANCE_SERVICE_FREQUENCY
# EVENT_LAUNCHING_SERVICE_FREQUENCY
# INTERMITTENT_CPU_RESET_SERVICE_FREQUENCY
# INTERMITTENT_STATE_PERTURB_SERVICES_FREQUENCY
# INTER_MESSAGE_COUNTER_CLEAR_SERVICE_FREQUENCY
# INTER_MESSAGE_LAUNCHING_SERVICE_FREQUENCY
# INTRA_MESSAGE_LAUNCHING_SERVICE_FREQUENCY
# STATE_OUTPUT_PUT_SERVICE_FREQUENCY
# PUSH_SERVICE_FREQUENCY
# QUORUM_CAP_SERVICE_FREQUENCY
# QUORUM_SERVICE_FREQUENCY
# RESOURCE_DECAY_SERVICE_FREQUENCY
# RESOURCE_HARVESTING_SERVICE_FREQUENCY
# RESOURCE_INPUT_JUMP_SERVICE_FREQUENCY
# RESOURCE_RECEIVING_SERVICE_FREQUENCY
# RESOURCE_SENDING_SERVICE_FREQUENCY
# SPAWN_SENDING_SERVICE_FREQUENCY
# STATE_INPUT_JUMP_SERVICE_FREQUENCY
# CONTROLLER_MAPPED_STATE_NOISE_SERVICE_FREQUENCY
# PHENOTYPE_EQUIVALENT_NOPOUT
# BATTLESHIP_PHENOTYPE_EQUIVALENT_NOPOUT
# JENGA_PHENOTYPE_EQUIVALENT_NOPOUT
# JENGA_NOP_OUT_SAVE_PROGRESS_AND_QUIT_SECONDS
# TEST_INTERROOT_PHENOTYPE_DIFFERENTIATION
# ALL_DRAWINGS_WRITE
# DATA_DUMP
# RUNNINGLOGS_DUMP
# CENSUS_WRITE
# ARTIFACTS_DUMP
# BENCHMARKING_DUMP
# ROOT_ABUNDANCES_FREQ
# ABORT_IF_COALESCENT_FREQ
# ABORT_IF_EXTINCT_FREQ
# ABORT_AT_LIVE_CELL_FRACTION
# REGULATION_VIZ_CLAMP
# RUNNING_LOG_DURATION
# SELECTED_DRAWINGS_FREQ
# DRAWING_WIDTH_PX
# DRAWING_HEIGHT_PX
# SELECTED_DRAWINGS
# ANIMATE_FRAMES
# VIDEO_FPS
# VIDEO_MAX_FRAMES
# Series
# Stint
# Flagged Advantageous Sites
# Flagged Deleterious Sites
# H_0 Advantageous Site Flags
# H_0 Deleterious Site Flags
# Estimated True Advantageous Sites
# Estimated True Deleterious Sites
# Num More Fit Under Extrospective State Rotates @ Intermittent P 1
# Num Less Fit Under Extrospective State Rotates @ Intermittent P 1
# Fraction Extrospective State Rotates that are Advantageous @ Intermittent P 1
# Fraction Extrospective State Rotates that are Deleterious @ Intermittent P 1
# Mean Extrospective State Rotate Fitness Differential @ Intermittent P 1
# Median Extrospective State Rotate Fitness Differential @ Intermittent P 1
# Num More Fit Under Extrospective State Rotates
# Num Less Fit Under Extrospective State Rotates
# Fraction Extrospective State Rotates that are Advantageous
# Fraction Extrospective State Rotates that are Deleterious
# Mean Extrospective State Rotate Fitness Differential
# Median Extrospective State Rotate Fitness Differential
# Num More Fit Under Extrospective State Exchanges @ Intermittent P 1
# Num Less Fit Under Extrospective State Exchanges @ Intermittent P 1
# Fraction Extrospective State Exchanges that are Advantageous @ Intermittent P 1
# Fraction Extrospective State Exchanges that are Deleterious @ Intermittent P 1
# Mean Extrospective State Exchange Fitness Differential @ Intermittent P 1
# Median Extrospective State Exchange Fitness Differential @ Intermittent P 1
# Num More Fit Under Extrospective State Exchanges
# Num Less Fit Under Extrospective State Exchanges
# Fraction Extrospective State Exchanges that are Advantageous
# Fraction Extrospective State Exchanges that are Deleterious
# Mean Extrospective State Exchange Fitness Differential
# Median Extrospective State Exchange Fitness Differential
# Num More Fit Under Introspective State Rotates @ Intermittent P 1
# Num Less Fit Under Introspective State Rotates @ Intermittent P 1
# Fraction Introspective State Rotates that are Advantageous @ Intermittent P 1
# Fraction Introspective State Rotates that are Deleterious @ Intermittent P 1
# Mean Introspective State Rotate Fitness Differential @ Intermittent P 1
# Median Introspective State Rotate Fitness Differential @ Intermittent P 1
# Num More Fit Under Introspective State Rotates
# Num Less Fit Under Introspective State Rotates
# Fraction Introspective State Rotates that are Advantageous
# Fraction Introspective State Rotates that are Deleterious
# Mean Introspective State Rotate Fitness Differential
# Median Introspective State Rotate Fitness Differential
# Num More Fit Under Introspective State Exchanges @ Intermittent P 1
# Num Less Fit Under Introspective State Exchanges @ Intermittent P 1
# Fraction Introspective State Exchanges that are Advantageous @ Intermittent P 1
# Fraction Introspective State Exchanges that are Deleterious @ Intermittent P 1
# Mean Introspective State Exchange Fitness Differential @ Intermittent P 1
# Median Introspective State Exchange Fitness Differential @ Intermittent P 1
# Num More Fit Under Introspective State Exchanges
# Num Less Fit Under Introspective State Exchanges
# Fraction Introspective State Exchanges that are Advantageous
# Fraction Introspective State Exchanges that are Deleterious
# Mean Introspective State Exchange Fitness Differential
# Median Introspective State Exchange Fitness Differential
# Num More Fit Under Writable State Rotates @ Intermittent P 1
# Num Less Fit Under Writable State Rotates @ Intermittent P 1
# Fraction Writable State Rotates that are Advantageous @ Intermittent P 1
# Fraction Writable State Rotates that are Deleterious @ Intermittent P 1
# Mean Writable State Rotate Fitness Differential @ Intermittent P 1
# Median Writable State Rotate Fitness Differential @ Intermittent P 1
# Num More Fit Under Writable State Rotates
# Num Less Fit Under Writable State Rotates
# Fraction Writable State Rotates that are Advantageous
# Fraction Writable State Rotates that are Deleterious
# Mean Writable State Rotate Fitness Differential
# Median Writable State Rotate Fitness Differential
# Num More Fit Under Writable State Exchanges @ Intermittent P 1
# Num Less Fit Under Writable State Exchanges @ Intermittent P 1
# Fraction Writable State Exchanges that are Advantageous @ Intermittent P 1
# Fraction Writable State Exchanges that are Deleterious @ Intermittent P 1
# Mean Writable State Exchange Fitness Differential @ Intermittent P 1
# Median Writable State Exchange Fitness Differential @ Intermittent P 1
# Num More Fit Under Writable State Exchanges
# Num Less Fit Under Writable State Exchanges
# Fraction Writable State Exchanges that are Advantageous
# Fraction Writable State Exchanges that are Deleterious
# Mean Writable State Exchange Fitness Differential
# Median Writable State Exchange Fitness Differential
# Num More Fit Under Extrospective State Perturbation @ Intermittent P 1
# Num Less Fit Under Extrospective State Perturbation @ Intermittent P 1
# Fraction Extrospective State Perturbations that are Advantageous @ Intermittent P 1
# Fraction Extrospective State Perturbations that are Deleterious @ Intermittent P 1
# Mean Extrospective State Perturbation Fitness Differential @ Intermittent P 1
# Median Extrospective State Perturbation Fitness Differential @ Intermittent P 1
# Num More Fit Under Extrospective State Perturbation
# Num Less Fit Under Extrospective State Perturbation
# Fraction Extrospective State Perturbations that are Advantageous
# Fraction Extrospective State Perturbations that are Deleterious
# Mean Extrospective State Perturbation Fitness Differential
# Median Extrospective State Perturbation Fitness Differential
# Num More Fit Under Introspective State Perturbation @ Intermittent P 1
# Num Less Fit Under Introspective State Perturbation @ Intermittent P 1
# Fraction Introspective State Perturbations that are Advantageous @ Intermittent P 1
# Fraction Introspective State Perturbations that are Deleterious @ Intermittent P 1
# Mean Introspective State Perturbation Fitness Differential @ Intermittent P 1
# Median Introspective State Perturbation Fitness Differential @ Intermittent P 1
# Num More Fit Under Introspective State Perturbation
# Num Less Fit Under Introspective State Perturbation
# Fraction Introspective State Perturbations that are Advantageous
# Fraction Introspective State Perturbations that are Deleterious
# Mean Introspective State Perturbation Fitness Differential
# Median Introspective State Perturbation Fitness Differential
# Num More Fit Under Writable State Perturbation @ Intermittent P 1
# Num Less Fit Under Writable State Perturbation @ Intermittent P 1
# Fraction Writable State Perturbations that are Advantageous @ Intermittent P 1
# Fraction Writable State Perturbations that are Deleterious @ Intermittent P 1
# Mean Writable State Perturbation Fitness Differential @ Intermittent P 1
# Median Writable State Perturbation Fitness Differential @ Intermittent P 1
# Num More Fit Under Writable State Perturbation
# Num Less Fit Under Writable State Perturbation
# Fraction Writable State Perturbations that are Advantageous
# Fraction Writable State Perturbations that are Deleterious
# Mean Writable State Perturbation Fitness Differential
# Median Writable State Perturbation Fitness Differential
# Num More Fit Under Inter Self-Send @ Filter Mod 20
# Num Less Fit Under Inter Self-Send @ Filter Mod 20
# Fraction Inter Self-Sends that are Advantageous @ Filter Mod 20
# Fraction Inter Self-Sends that are Deleterious @ Filter Mod 20
# Mean Inter Self-Send Fitness Differential @ Filter Mod 20
# Median Inter Self-Send Fitness Differential @ Filter Mod 20
# Num More Fit Under Inter Self-Send
# Num Less Fit Under Inter Self-Send
# Fraction Inter Self-Sends that are Advantageous
# Fraction Inter Self-Sends that are Deleterious
# Mean Inter Self-Send Fitness Differential
# Median Inter Self-Send Fitness Differential
# Num More Fit Under Intra Self-Send @ Filter Mod 20
# Num Less Fit Under Intra Self-Send @ Filter Mod 20
# Fraction Intra Self-Sends that are Advantageous @ Filter Mod 20
# Fraction Intra Self-Sends that are Deleterious @ Filter Mod 20
# Mean Intra Self-Send Fitness Differential @ Filter Mod 20
# Median Intra Self-Send Fitness Differential @ Filter Mod 20
# Num More Fit Under Intra Self-Send
# Num Less Fit Under Intra Self-Send
# Fraction Intra Self-Sends that are Advantageous
# Fraction Intra Self-Sends that are Deleterious
# Mean Intra Self-Send Fitness Differential
# Median Intra Self-Send Fitness Differential
# Num More Fit Mutants
# Num Less Fit Mutants
# Fraction Mutations that are Advantageous
# Fraction Mutations that are Deleterious
# Mean Mutant Fitness Differential
# Median Mutant Fitness Differential
# Num More Fit Mutating Mutants
# Num Less Fit Mutating Mutants
# Fraction Mutating Mutations that are Advantageous
# Fraction Mutating Mutations that are Deleterious
# Mean Mutating Mutant Fitness Differential
# Median Mutating Mutant Fitness Differential
# Mean Doubling Time Growth Rate
# Test Stint
# Test Series
# Test Replicate
# Test Treatment
# Treatment _
# Treatment mut_sever
# Treatment mut_freq
# Treatment diversity
# Treatment bucket
# Test Endeavor
# Test Repro
# Competition Slurm Job ID
# Test Thread
# Test Process
# Update
# First Root ID
# Second Root ID
# First Genome Slug
# Second Genome Slug
# First Genome Filename
# Second Genome Filename
# Phenotype Divergence Detected
# first genome a
# first genome criteria
# first genome ext
# first genome morph
# first genome proc
# first genome root_id
# first genome series
# first genome stint
# first genome thread
# first genome variation
# second genome a
# second genome criteria
# second genome ext
# second genome morph
# second genome proc
# second genome root_id
# second genome series
# second genome stint
# second genome thread
# second genome variation
# Phenotype Neutral Nopout is Phenotypically Divergent
# Phenotype Neutral Nopout is Phenotypically Identical
# Fraction Phenotypically-Expressed Mutations
# Fraction Phenotypically-Neutral Mutations
# Mean Fitness Differential Against Predecessor Population
# Fraction Predecessor Battles Won
# Predecessor Battle Null p-value
# index
# Treatment
# 0
# Genome Slug
# Genome Filename
# Num Anchor Instructions
# Num Global Anchor Instructions
# Num Local Anchor Instructions
# Num Bitwise Instructions
# Num Intermessaging Instructions
# Num Intrinsic Instructions
# Num Extrinsic Instructions
# Num Flow Instructions
# Num Global Flow Instructions
# Num Local Flow Instructions
# Num Nop Instructions
# Num Op Instructions
# Num Actuator Instructions
# Num Calculation Instructions
# Num Regulation Instructions
# Num Global Regulation Instructions
# Num Local Regulation Instructions
# Program Compression Ratio
# Num Instructions
# Num Modules
# Coding Fraction
# Non-coding Fraction
# Elapsed Generations Level 0
# Elapsed Generations Level 1
# Elapsed Generations Level 2
# Elapsed Indel Mutations
# Elapsed Point Mutations
# Elapsed Mutations
# genome _
# genome _endeavor
# genome _repro
# genome _slurm_job_id
# genome _source
# genome _treatment
# genome a
# genome abundance
# genome count
# genome criteria
# genome ext
# genome morph
# genome prevalence
# genome proc
# genome series
# genome stint
# genome thread
# genome variation
# Phenotype Complexity
# Parent-Eliminated Kin ID Commonality=1+a=Treatment
# Parent-Eliminated Kin ID Commonality=2+a=Treatment
# Parent-Eliminated Kin ID Commonality=1+a=Treatment _
# Parent-Eliminated Kin ID Commonality=2+a=Treatment _
# Parent-Eliminated Kin ID Commonality=1+a=Treatment mut_sever
# Parent-Eliminated Kin ID Commonality=2+a=Treatment mut_sever
# Parent-Eliminated Kin ID Commonality=1+a=Treatment mut_freq
# Parent-Eliminated Kin ID Commonality=2+a=Treatment mut_freq
# Parent-Eliminated Kin ID Commonality=1+a=Treatment diversity
# Parent-Eliminated Kin ID Commonality=2+a=Treatment diversity
# Parent-Eliminated Kin ID Commonality=1+a=Treatment bucket
# Parent-Eliminated Kin ID Commonality=2+a=Treatment bucket
# Parent-Eliminated Kin ID Commonality=1+a=proc
# Parent-Eliminated Kin ID Commonality=2+a=proc
# Parent-Eliminated Kin ID Commonality=1+a=thread
# Parent-Eliminated Kin ID Commonality=2+a=thread
# Parent-Eliminated Kin ID Commonality=1+a=Num Spawn Events
# Parent-Eliminated Kin ID Commonality=2+a=Num Spawn Events
# Parent-Eliminated Kin ID Commonality=1+a=Total Num Neighbors
# Parent-Eliminated Kin ID Commonality=2+a=Total Num Neighbors
# Parent-Eliminated Kin ID Commonality=1+a=Total Num Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+a=Total Num Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+a=Total Num Spawn Event Neighbors
# Parent-Eliminated Kin ID Commonality=2+a=Total Num Spawn Event Neighbors
# Parent-Eliminated Kin ID Commonality=1+a=Total Num Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+a=Total Num Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+a=Total Num Kin Eliminated
# Parent-Eliminated Kin ID Commonality=2+a=Total Num Kin Eliminated
# Parent-Eliminated Kin ID Commonality=1+a=Fraction Eliminated that are Kin
# Parent-Eliminated Kin ID Commonality=2+a=Fraction Eliminated that are Kin
# Parent-Eliminated Kin ID Commonality=1+a=Fraction Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+a=Fraction Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+a=Fraction Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+a=Fraction Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+a=Kin Conflict Ratio
# Parent-Eliminated Kin ID Commonality=2+a=Kin Conflict Ratio
# Parent-Eliminated Kin ID Commonality=1+a=Kin Conflict at Spawn Ratio
# Parent-Eliminated Kin ID Commonality=2+a=Kin Conflict at Spawn Ratio
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Treatment
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Treatment
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Treatment
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Treatment
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Treatment
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Treatment
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Treatment _
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Treatment _
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Treatment _
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Treatment _
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Treatment _
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Treatment _
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Treatment mut_sever
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Treatment mut_sever
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Treatment mut_sever
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Treatment mut_sever
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Treatment mut_sever
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Treatment mut_sever
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Treatment mut_freq
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Treatment mut_freq
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Treatment mut_freq
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Treatment mut_freq
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Treatment mut_freq
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Treatment mut_freq
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Treatment diversity
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Treatment diversity
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Treatment diversity
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Treatment diversity
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Treatment diversity
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Treatment diversity
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Treatment bucket
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Treatment bucket
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Treatment bucket
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Treatment bucket
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Treatment bucket
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Treatment bucket
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=proc
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=proc
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=proc
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=proc
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=proc
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=proc
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=thread
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=thread
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=thread
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=thread
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=thread
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=thread
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Num Spawn Events
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Num Spawn Events
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Num Spawn Events
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Num Spawn Events
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Num Spawn Events
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Num Spawn Events
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Total Num Neighbors
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Total Num Neighbors
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Total Num Neighbors
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Total Num Neighbors
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Total Num Neighbors
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Total Num Neighbors
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Total Num Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Total Num Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Total Num Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Total Num Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Total Num Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Total Num Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Total Num Spawn Event Neighbors
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Total Num Spawn Event Neighbors
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Total Num Spawn Event Neighbors
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Total Num Spawn Event Neighbors
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Total Num Spawn Event Neighbors
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Total Num Spawn Event Neighbors
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Total Num Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Total Num Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Total Num Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Total Num Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Total Num Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Total Num Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Total Num Kin Eliminated
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Total Num Kin Eliminated
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Total Num Kin Eliminated
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Total Num Kin Eliminated
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Total Num Kin Eliminated
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Total Num Kin Eliminated
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Fraction Eliminated that are Kin
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Fraction Eliminated that are Kin
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Fraction Eliminated that are Kin
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Fraction Eliminated that are Kin
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Fraction Eliminated that are Kin
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Fraction Eliminated that are Kin
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Fraction Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Fraction Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Fraction Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Fraction Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Fraction Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Fraction Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Fraction Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Fraction Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Fraction Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Fraction Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Fraction Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Fraction Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Kin Conflict Ratio
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Kin Conflict Ratio
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Kin Conflict Ratio
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Kin Conflict Ratio
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Kin Conflict Ratio
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Kin Conflict Ratio
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Kin Conflict at Spawn Ratio
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Kin Conflict at Spawn Ratio
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Kin Conflict at Spawn Ratio
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Kin Conflict at Spawn Ratio
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Kin Conflict at Spawn Ratio
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Kin Conflict at Spawn Ratio
# Cardinal Apoptosis Request Fraction
# Cell Apoptosis Request Fraction
# Extinct
# Fecund Resource Stockpile Fraction
# Fraction Deaths age
# Fraction Deaths apoptosis
# Fraction Deaths elimination
# Fraction Deaths fragmentation
# Fraction Deaths quorum
# Fraction Deaths unknown
# Fraction Kin Group Loner Cells Level 0
# Fraction Kin Group Loner Cells Level 1
# Fraction Live Cells
# Fraction Neighbors Kin Level 0
# Fraction Neighbors Kin Level 1
# Incoming Inter Message Cardinal Fraction
# Incoming Inter Message Cell Fraction
# Incoming Intra Message Cardinal Fraction
# Incoming Intra Message Cell Fraction
# Maximum Kin Group Size Level 0
# Maximum Kin Group Size Level 1
# Mean Cell Age
# Mean Current Epoch
# Mean Elapsed Generations Level 0
# Mean Elapsed Generations Level 1
# Mean Elapsed Generations Level 2
# Mean Elapsed Indel Mutations
# Mean Elapsed Mutation Occurences
# Mean Elapsed Point Mutations
# Mean Incoming Inter Message Count Per Cardinal
# Mean Incoming Inter Message Count Per Cell
# Mean Incoming Intra Message Count Per Cardinal
# Mean Incoming Intra Message Count Per Cell
# Mean Instructions Executed per Cardinal-update
# Mean Kin Group Age Level 0
# Mean Kin Group Age Level 1
# Mean Kin Group Size Level 0
# Mean Kin Group Size Level 1
# Mean Program Instruction Count
# Mean Program Module Count
# Mean Resource Received Per Cardinal
# Mean Resource Received Per Cell
# Mean Resource Stockpile
# Mean Spawn Count
# Median Kin Group Size Level 0
# Median Kin Group Size Level 1
# Nulliparous Fraction
# Num Births per Cell-update
# Num Births per Live Cell-update
# Num Deaths age
# Num Deaths apoptosis
# Num Deaths elimination
# Num Deaths fragmentation
# Num Deaths per Cell-update
# Num Deaths per Cell-update age
# Num Deaths per Cell-update apoptosis
# Num Deaths per Cell-update elimination
# Num Deaths per Cell-update fragmentation
# Num Deaths per Cell-update quorum
# Num Deaths per Cell-update unknown
# Num Deaths per Live Cell-update
# Num Deaths per Live Cell-update age
# Num Deaths per Live Cell-update apoptosis
# Num Deaths per Live Cell-update elimination
# Num Deaths per Live Cell-update fragmentation
# Num Deaths per Live Cell-update quorum
# Num Deaths per Live Cell-update unknown
# Num Deaths quorum
# Num Deaths unknown
# Num Instructions Executed per Live Cardinal-update
# Num Spawn Events per Cell-update
# Num Spawn Events per Live Cell-update
# Number Cardinals
# Number Cells
# Number Dead Cells
# Number Live Cardinals
# Number Live Cells
# Number Phylogenetic Roots
# Number Stint Phylogenetic Roots
# Number Unique Genotypes
# Number Unique Module Expression Profiles
# Number Unique Module Regulation Profiles
# Prevalent Genotype Quantity
# Random Number Generator Seed
# Resource Receive Resistance Cardinal Fraction
# Resource Receive Resistance Cell Fraction
# Resource Receiving Cardinal Fraction
# Resource Receiving Cell Fraction
# Resource Reserve Request Cardinal Fraction
# Resource Reserve Request Cell Fraction
# Resource Send Request Cardinal Fraction
# Resource Send Request Cell Fraction
# Spawn Arrest Cardinal Fraction
# Spawn Arrest Cell Fraction
# Spawn Request Cardinal Fraction
# Spawn Request Cell Fraction
# Fitness Complexity
# Expected Mutations
# Mutation Accumulation
# Elapsed Generations
# Selection Pressure
# % Generations Level 0
# % Generations Level 1
# % Generations Level 2
# Mean Mutations per Generation
# Fitness Complexity Delta
# Fitness Complexity Delta %
# Fitness Complexity Delta Sign
# Phenotype Complexity Delta
# Phenotype Complexity Delta %
# Phenotype Complexity Delta Sign
# Predecessor Battle Outcome
# Neutral Phenotypic Variation Under Mutation
# Fraction Phenotypic Variation That Is Neutral Under Mutation
# Num Less Fit Under State Exchanges
# Num Less Fit Under State Rotates
# Num Less Fit Under State Perturbation
# Cardinal Interface Complexity
# Cell Interface Complexity
