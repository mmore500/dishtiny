# %%
import pandas as pd

# %% [markdown]
# download dataset via Open Science Framework

# %%
df = pd.read_csv(
    'https://osf.io/vcfa9/download',
    compression='xz',
)

# %%
# run me to see a formatted preview of the dataset
df
# Out:
#     Series  Mean Inter-Strain Fitness Differential  \
# 0    11000                               -0.000025
# 1    11001                               -0.000033
# 2    11002                               -0.000204
# 3    11003                                0.000937
# 4    11004                               -0.000102
# ..     ...                                     ...
# 75   11035                                0.000037
# 76   11036                               -0.000106
# 77   11037                               -0.000205
# 78   11038                               -0.000061
# 79   11039                               -0.000064
#
#     Fraction Inter-Strain Competitions Won  \
# 0                                     0.45
# 1                                     0.50
# 2                                     0.30
# 3                                     0.95
# 4                                     0.50
# ..                                     ...
# 75                                    0.70
# 76                                    0.40
# 77                                    0.10
# 78                                    0.50
# 79                                    0.60
#
#     Inter-Strain Competition Null p-value  Flagged Advantageous Sites  \
# 0                                0.823803                          11
# 1                                1.000000                          10
# 2                                0.115318                           2
# 3                                0.000040                          10
# 4                                1.000000                           9
# ..                                    ...                         ...
# 75                               0.115318                          13
# 76                               0.503445                           8
# 77                               0.000402                          11
# 78                               1.000000                          10
# 79                               0.503445                           7
#
#     Flagged Deleterious Sites  H_0 Advantageous Site Flags  \
# 0                           0                         0.51
# 1                           2                         0.29
# 2                           0                         0.06
# 3                           3                         0.36
# 4                           0                         0.11
# ..                        ...                          ...
# 75                          0                         0.74
# 76                          0                         0.85
# 77                          0                         0.48
# 78                          1                         0.43
# 79                          0                         0.69
#
#     H_0 Deleterious Site Flags  Estimated True Advantageous Sites  \
# 0                         0.51                              10.49
# 1                         0.29                               9.71
# 2                         0.06                               1.94
# 3                         0.36                               9.64
# 4                         0.11                               8.89
# ..                         ...                                ...
# 75                        0.74                              12.26
# 76                        0.85                               7.15
# 77                        0.48                              10.52
# 78                        0.43                               9.57
# 79                        0.69                               6.31
#
#     Estimated True Deleterious Sites  ...  \
# 0                              -0.51  ...
# 1                               1.71  ...
# 2                              -0.06  ...
# 3                               2.64  ...
# 4                              -0.11  ...
# ..                               ...  ...
# 75                             -0.74  ...
# 76                             -0.85  ...
# 77                             -0.48  ...
# 78                              0.57  ...
# 79                             -0.69  ...
#
#     Resource Receiving Cardinal Fraction  Resource Receiving Cell Fraction  \
# 0                               0.003760                          0.015040
# 1                               0.003528                          0.014113
# 2                               0.002575                          0.010302
# 3                               0.001707                          0.006830
# 4                               0.002780                          0.011122
# ..                                   ...                               ...
# 75                              0.029764                          0.116396
# 76                              0.036085                          0.139590
# 77                              0.003910                          0.015639
# 78                              0.058918                          0.220250
# 79                              0.001653                          0.006613
#
#     Resource Reserve Request Cardinal Fraction  \
# 0                                     0.484576
# 1                                     0.013525
# 2                                     0.013588
# 3                                     0.319650
# 4                                     0.012552
# ..                                         ...
# 75                                    0.014993
# 76                                    0.073136
# 77                                    0.216731
# 78                                    0.998545
# 79                                    0.019312
#
#     Resource Reserve Request Cell Fraction  \
# 0                                 0.782075
# 1                                 0.052926
# 2                                 0.053996
# 3                                 0.557484
# 4                                 0.047982
# ..                                     ...
# 75                                0.058493
# 76                                0.156222
# 77                                0.597226
# 78                                0.999709
# 79                                0.075443
#
#     Resource Send Request Cardinal Fraction  \
# 0                                  0.246931
# 1                                  0.013893
# 2                                  0.012877
# 3                                  0.013588
# 4                                  0.013267
# ..                                      ...
# 75                                 0.013146
# 76                                 0.013068
# 77                                 0.014016
# 78                                 0.015130
# 79                                 0.013375
#
#     Resource Send Request Cell Fraction  Spawn Arrest Cardinal Fraction  \
# 0                              0.504604                        0.012201
# 1                              0.054690                        0.013672
# 2                              0.051510                        0.010391
# 3                              0.053216                        0.015723
# 4                              0.051478                        0.108119
# ..                                  ...                             ...
# 75                             0.051403                        0.014328
# 76                             0.050787                        0.486932
# 77                             0.055769                        0.002508
# 78                             0.059354                        0.925007
# 79                             0.052600                        0.098137
#
#     Spawn Arrest Cell Fraction Spawn Request Cardinal Fraction  \
# 0                     0.048189                        0.352594
# 1                     0.054102                        0.295354
# 2                     0.041208                        0.326021
# 3                     0.061468                        0.075911
# 4                     0.253575                        0.543772
# ..                         ...                             ...
# 75                    0.055835                        0.440177
# 76                    0.894268                        0.390852
# 77                    0.010032                        0.295958
# 78                    0.999709                        0.997090
# 79                    0.222122                        0.106102
#
#    Spawn Request Cell Fraction
# 0                     0.707489
# 1                     0.683916
# 2                     0.716874
# 3                     0.195788
# 4                     0.865269
# ..                         ...
# 75                    0.745938
# 76                    0.679537
# 77                    0.651815
# 78                    0.999709
# 79                    0.306583
#
# [80 rows x 242 columns]

# %% [markdown]
# add your own analyses below!
